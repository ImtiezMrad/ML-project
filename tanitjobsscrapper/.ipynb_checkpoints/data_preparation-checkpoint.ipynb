# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("emploi.csv")
df.head(20)
# Out:
#                                             Job Title  \
# 0             Business Developer Anglophone​ - Ariana
# 1                        Community Manager - Monastir
# 2   Docteur en Data Science ou en Informatique - A...
# 3            Formation en Data Engineer (F/H) - Paris
# 4   Consultant Fonctionnel Sage XRT ou Sage FRP 10...
# 5   Chargé(e) de Partenariats et Relations Presse ...
# 6                         Technico-commercial - Tunis
# 7   Coordinateur(trice) Pédagogique et Administrat...
# 8               Spécialiste Contrôle Qualité - Raoued
# 9                           Web Développer - Monastir
# 10                 Femme de Chambre / Ménage  - Tunis
# 11                            Coiffeur Maquilleur H/F
# 12        Secrétaire de Garage Mécanique H/F - Ariana
# 13  Commercial en Assurance Auto, Vie et Santé - T...
# 14                 Agent de Transit  - Tunis Carthage
# 15                                  Chauffeur Livreur
# 16                               Technicien Supérieur
# 17                                         Magasinier
# 18            Web & Graphique Designer H/F - la Marsa
# 19     Community Manager / Content Creator - la Marsa
#
#                        Company Name  Job Description  \
# 0                     SMART CONSEIL              NaN
# 1                    TAHRI COMPAGNE              NaN
# 2                     SMART CONSEIL              NaN
# 3                         KAISCHOOL              NaN
# 4           DELTASOFT INTERNATIONAL              NaN
# 5                     SMART CONSEIL              NaN
# 6                  SEMO ART ET DECO              NaN
# 7                       ECOLE CONTE              NaN
# 8                        MACOPHARMA              NaN
# 9                    TAHRI COMPAGNE              NaN
# 10                 VILLA LES PALMES              NaN
# 11                       MAGIC HAIR              NaN
# 12                 GARAGE MÉCANIQUE              NaN
# 13                   ATOLL-SERVICES              NaN
# 14  AGS CARTHAGO MOVING AND STORAGE              NaN
# 15                      AGRIA-GROUP              NaN
# 16                        TECHNOPRO              NaN
# 17                      AGRIA-GROUP              NaN
# 18       DIGITAURA MARKETING AGENCY              NaN
# 19       DIGITAURA MARKETING AGENCY              NaN
#
#                                           Study Level  \
# 0     Bac, Bac+1, Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 1                                               Bac+3
# 2                                       Bac+5 et plus
# 3                        Bac+3, Bac+4 & Bac+5 et plus
# 4                                       Bac+5 et plus
# 5   Qualification avant bac, Bac, Bac+1, Bac+2, Ba...
# 6                 Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 7                               Bac+4 & Bac+5 et plus
# 8                               Bac+4 & Bac+5 et plus
# 9                                       Bac+5 et plus
# 10                            Qualification avant bac
# 11                                                Bac
# 12                                                Bac
# 13                                              Bac+3
# 14                                                Bac
# 15                                                Bac
# 16                                              Bac+3
# 17                                              Bac+1
# 18                Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 19                Bac+2, Bac+3, Bac+4 & Bac+5 et plus
#
#                                      Experience Level  \
# 0                     Etudiant, jeune diplômé et plus
# 1                            Débutant < 2 ans et plus
# 2             Expérience entre 2 ans et 5 ans et plus
# 3                     Etudiant, jeune diplômé et plus
# 4                     Expérience entre 2 ans et 5 ans
# 5                     Etudiant, jeune diplômé et plus
# 6             Expérience entre 2 ans et 5 ans et plus
# 7   Débutant < 2 ans & Expérience entre 2 ans et 5...
# 8                            Débutant < 2 ans et plus
# 9             Expérience entre 2 ans et 5 ans et plus
# 10                                   Débutant < 2 ans
# 11                    Expérience entre 2 ans et 5 ans
# 12                    Expérience entre 2 ans et 5 ans
# 13                    Expérience entre 2 ans et 5 ans
# 14                    Expérience entre 2 ans et 5 ans
# 15                    Expérience entre 2 ans et 5 ans
# 16                            Etudiant, jeune diplômé
# 17                    Expérience entre 2 ans et 5 ans
# 18                           Débutant < 2 ans et plus
# 19                           Débutant < 2 ans et plus
#
#                                Contract Type  \
# 0                           CDI, CDD & Stage
# 1                                        CDI
# 2                                  CDI - CDD
# 3                                 Alternance
# 4                           CDI - Statutaire
# 5   CDI, CDD, Intérim, Stage & Temps partiel
# 6                                        CDD
# 7                                        CDI
# 8                                        CDD
# 9                                        CDI
# 10                                Statutaire
# 11                                 CDI & CDD
# 12                                       CDI
# 13                                       CDI
# 14                                       CDI
# 15                                Statutaire
# 16                               CDD & Stage
# 17                                Statutaire
# 18                                       CDD
# 19                             Temps partiel
#
#                                                Region  \
# 0                              Ariana & International
# 1                                            Monastir
# 2   Ariana - Béja - Ben Arous - Bizerte - Gabès - ...
# 3                                       International
# 4   Ariana - Béja - Ben Arous - Bizerte - Gabès - ...
# 5                                       International
# 6                            Ariana - Manouba & Tunis
# 7                                               Tunis
# 8                                              Ariana
# 9                                            Monastir
# 10                                              Tunis
# 11                                              Tunis
# 12                                             Ariana
# 13                         Ariana - Ben Arous & Tunis
# 14                                  Ben Arous & Tunis
# 15                                           Monastir
# 16                                               Sfax
# 17                                           Monastir
# 18                                     Ariana & Tunis
# 19                                              Tunis
#
#                                                Skills Posting Date  \
# 0              Gestion d'Équipe - Prospection - Vente   30.11.2024
# 1   Analyse Marketing - Communication - Communicat...   30.11.2024
# 2                                                 NaN   30.11.2024
# 3   APACHE - BIG DATA - Comptabilité - Finance - G...   30.11.2024
# 4   Comptabilité - Finance - Gestion - SAGE - TMS ...   30.11.2024
# 5   Communication - Communication Externe - Rédaction   30.11.2024
# 6   3DS MAX - Architecture d'Intérieur - Devis - V...   30.11.2024
# 7   Accompagnement - Administration - Assistanat -...   30.11.2024
# 8   Assurance Qualité - Chimie - GMP - Maintenance...   30.11.2024
# 9   Communication - CSS - Design - HTML - JAVASCRI...   30.11.2024
# 10                                           Tourisme   29.11.2024
# 11                                                NaN   29.11.2024
# 12  Accueil Physique - Assistanat - Devis - Dossie...   29.11.2024
# 13            Techniques de Vente - Télévente - Vente   29.11.2024
# 14                                Transit - Transport   29.11.2024
# 15  Livraison - Sécurité - Sécurité Routière - Tra...   29.11.2024
# 16                               Production - Qualité   29.11.2024
# 17  Achats - Chargement - Déchargement - Distribut...   29.11.2024
# 18  Assembly Design - CSS - Design - HTML - Newsle...   29.11.2024
# 19  Communication - Community Management - Content...   29.11.2024
#
#                                              Job Link
# 0   https://www.emploitunisie.com/offre-emploi-tun...
# 1   https://www.emploitunisie.com/offre-emploi-tun...
# 2   https://www.emploitunisie.com/offre-emploi-tun...
# 3   https://www.emploitunisie.com/offre-emploi-tun...
# 4   https://www.emploitunisie.com/offre-emploi-tun...
# 5   https://www.emploitunisie.com/offre-emploi-tun...
# 6   https://www.emploitunisie.com/offre-emploi-tun...
# 7   https://www.emploitunisie.com/offre-emploi-tun...
# 8   https://www.emploitunisie.com/offre-emploi-tun...
# 9   https://www.emploitunisie.com/offre-emploi-tun...
# 10  https://www.emploitunisie.com/offre-emploi-tun...
# 11  https://www.emploitunisie.com/offre-emploi-tun...
# 12  https://www.emploitunisie.com/offre-emploi-tun...
# 13  https://www.emploitunisie.com/offre-emploi-tun...
# 14  https://www.emploitunisie.com/offre-emploi-tun...
# 15  https://www.emploitunisie.com/offre-emploi-tun...
# 16  https://www.emploitunisie.com/offre-emploi-tun...
# 17  https://www.emploitunisie.com/offre-emploi-tun...
# 18  https://www.emploitunisie.com/offre-emploi-tun...
# 19  https://www.emploitunisie.com/offre-emploi-tun...

# %%
df['Company Name'].value_counts()
# Out:
# Company Name
# AFRICASHORE                42
# SMART CONSEIL               9
# ALTRACALL                   5
# SOPROTIC                    3
# ANC                         3
#                            ..
# BATIPRO                     1
# COGEB IMMOBILIERE           1
# PHARMACIE LAATIG RADHIA     1
# GRAPHIKA                    1
# PI 2R                       1
# Name: count, Length: 144, dtype: int64

# %%
df1 = pd.read_csv("keejob.csv")
df1.head(20)
# Out:
#                                          Title  \
# 0                           Conseillers Client
# 1      Chargé(e) de Service Clientèle - Sousse
# 2                      Développeur Java Medior
# 3                                    Acheteuse
# 4                     Ingénieur Qualité Client
# 5                   Gestionnaire de Paie (H/F)
# 6                       Architecte d'intérieur
# 7                     Customer Service Support
# 8    assistant responsable magasin STRASS SFAX
# 9                                   Chargée RH
# 10    Magasinier Pièces de Rechange Automobile
# 11       Chasseur / Chasseuse de tête (Sousse)
# 12          Technicien supérieur mécanique H/F
# 13                      Juriste en droit privé
# 14               Ingénieur Maintenance PEC MED
# 15  Agent Technique / Unité des Graisses (H/F)
# 16      Chargé (e) administration du personnel
# 17                                   Comptable
# 18                              Chef Comptable
# 19                       Contrôleur de Gestion
#
#                                 Company   Location              Job Type  \
# 0                       TELEPERFORMANCE      Tunis                   CDI
# 1                              BANK ABC      Tunis           Unspecified
# 2                               BINITNS      Tunis                   CDI
# 3   PLASTIC ELECTROMECHANIC COMPANY PEC   Zaghouan           CDI, ,, CDD
# 4                           ASTEELFLASH     Ariana           Unspecified
# 5                                 ARTUS   Monastir           CDI, ,, CDD
# 6                                   NaN   Monastir           Unspecified
# 7                            OUTSOURCIA     Ariana          CDI, ,, SIVP
# 8                                   NaN       Sfax          CDD, ,, SIVP
# 9                           ASTEELFLASH     Ariana                   CDI
# 10                                  NaN     Ariana          CDD, ,, SIVP
# 11               VEO WORLDWIDE SERVICES     Sousse           Unspecified
# 12                             Manpower    Bizerte                   CDD
# 13                POULINA GROUP HOLDING  Ben Arous          CDD, ,, SIVP
# 14  PLASTIC ELECTROMECHANIC COMPANY PEC   Zaghouan                   CDD
# 15               HR HOUSE INTERNATIONAL    Bizerte                   CDI
# 16                           OUTSOURCIA     Ariana          CDI, ,, SIVP
# 17                AGENCE CITROËN MNIHLA     Ariana  CDI, ,, CDD, ,, SIVP
# 18                                APTIV       Béja                   CDI
# 19                          ASTEELFLASH     Ariana                   CDI
#
#                                              Job Link  Référence  \
# 0   https://www.keejob.com/offres-emploi/211206/co...     211206
# 1   https://www.keejob.com/offres-emploi/210308/ch...     210308
# 2   https://www.keejob.com/offres-emploi/211371/d%...     211371
# 3   https://www.keejob.com/offres-emploi/211433/ac...     211433
# 4   https://www.keejob.com/offres-emploi/212102/in...     212102
# 5   https://www.keejob.com/offres-emploi/212099/ge...     212099
# 6   https://www.keejob.com/offres-emploi/212037/ar...     212037
# 7   https://www.keejob.com/offres-emploi/211714/cu...     211714
# 8   https://www.keejob.com/offres-emploi/211166/as...     211166
# 9   https://www.keejob.com/offres-emploi/211745/ch...     211745
# 10  https://www.keejob.com/offres-emploi/210626/ma...     210626
# 11  https://www.keejob.com/offres-emploi/211205/ch...     211205
# 12  https://www.keejob.com/offres-emploi/212103/te...     212103
# 13  https://www.keejob.com/offres-emploi/210615/ju...     210615
# 14  https://www.keejob.com/offres-emploi/211434/in...     211434
# 15  https://www.keejob.com/offres-emploi/210587/un...     210587
# 16  https://www.keejob.com/offres-emploi/212087/ch...     212087
# 17  https://www.keejob.com/offres-emploi/210623/ag...     210623
# 18  https://www.keejob.com/offres-emploi/212125/ch...     212125
# 19  https://www.keejob.com/offres-emploi/211585/co...     211585
#
#           Publiée le         Type de poste  \
# 0   29 novembre 2024                   CDI
# 1   29 novembre 2024                   NaN
# 2   29 novembre 2024                   CDI
# 3   29 novembre 2024           CDI, ,, CDD
# 4   29 novembre 2024                   NaN
# 5   29 novembre 2024           CDI, ,, CDD
# 6   29 novembre 2024                   NaN
# 7   29 novembre 2024          CDI, ,, SIVP
# 8   29 novembre 2024          CDD, ,, SIVP
# 9   29 novembre 2024                   CDI
# 10  29 novembre 2024          CDD, ,, SIVP
# 11  29 novembre 2024                   NaN
# 12  29 novembre 2024                   CDD
# 13  29 novembre 2024          CDD, ,, SIVP
# 14  29 novembre 2024                   CDD
# 15  29 novembre 2024                   CDI
# 16  29 novembre 2024          CDI, ,, SIVP
# 17  29 novembre 2024  CDI, ,, CDD, ,, SIVP
# 18  29 novembre 2024                   CDI
# 19  29 novembre 2024                   CDI
#
#                        Lieu de travail         Expérience  \
# 0         Centre ville, Tunis, Tunisie  Aucune expérience
# 1                       Tunis, Tunisie      Moins d'un an
# 2                       Tunis, Tunisie   Entre 2 et 5 ans
# 3       Bir Mcherga, Zaghouan, Tunisie   Entre 2 et 5 ans
# 4                      Ariana, Tunisie   Entre 2 et 5 ans
# 5                    Monastir, Tunisie   Entre 2 et 5 ans
# 6        Ksar Helal, Monastir, Tunisie   Entre 1 et 2 ans
# 7        Ariana Ville, Ariana, Tunisie   Entre 1 et 2 ans
# 8          Sakiet Ezzit, Sfax, Tunisie   Entre 1 et 2 ans
# 9                      Ariana, Tunisie   Entre 2 et 5 ans
# 10             Mnihla, Ariana, Tunisie   Entre 2 et 5 ans
# 11                     Sousse, Tunisie   Entre 1 et 2 ans
# 12  Menzel Bourguiba, Bizerte, Tunisie   Entre 1 et 2 ans
# 13         Ezzahra, Ben Arous, Tunisie  Aucune expérience
# 14     Hammam Zriba, Zaghouan, Tunisie   Entre 1 et 2 ans
# 15                    Bizerte, Tunisie   Entre 1 et 2 ans
# 16       Ariana Ville, Ariana, Tunisie   Entre 1 et 2 ans
# 17             Mnihla, Ariana, Tunisie   Entre 2 et 5 ans
# 18         Mejez El Bab, Béja, Tunisie    Plus que 10 ans
# 19          La Soukra, Ariana, Tunisie  Entre 5 et 10 ans
#
#                           Étude Disponibilité                     Langues  \
# 0                    Secondaire   Plein temps                    Français
# 1                       Bac + 3   Plein temps                         NaN
# 2                       Bac + 5   Plein temps                    Français
# 3                       Bac + 3   Plein temps          Français , Anglais
# 4                       Bac + 5   Plein temps          Français , Anglais
# 5                       Bac + 5   Plein temps          Français , Anglais
# 6                       Bac + 5   Plein temps                         NaN
# 7                       Bac + 2   Plein temps          Français , Anglais
# 8                       Bac + 3   Plein temps  Arabe , Français , Anglais
# 9                       Bac + 3   Plein temps  Arabe , Français , Anglais
# 10  Formations professionnelles   Plein temps  Arabe , Français , Anglais
# 11                      Bac + 3   Plein temps                    Français
# 12  Formations professionnelles   Plein temps                    Français
# 13                      Bac + 5   Plein temps  Arabe , Français , Anglais
# 14                      Bac + 5   Plein temps          Français , Anglais
# 15  Formations professionnelles   Plein temps                         NaN
# 16                      Bac + 2   Plein temps  Arabe , Français , Anglais
# 17                      Bac + 3   Plein temps            Arabe , Français
# 18                      Bac + 5   Plein temps  Arabe , Français , Anglais
# 19                      Bac + 5   Plein temps          Français , Anglais
#
#                    Salary               Mobility
# 0                     NaN                    NaN
# 1                     NaN                    NaN
# 2                     NaN                    NaN
# 3                     NaN          International
# 4         1 - 0 DT / Mois                    NaN
# 5        1400 - DT / Mois                    NaN
# 6    600 - 1000 DT / Mois                 Locale
# 7   1000 - 1500 DT / Mois                    NaN
# 8                     NaN                    NaN
# 9                     NaN                    NaN
# 10   600 - 1000 DT / Mois                    NaN
# 11                    NaN          International
# 12        700 - DT / Mois                    NaN
# 13                    NaN                 Locale
# 14                    NaN                    NaN
# 15                    NaN                    NaN
# 16                    NaN                    NaN
# 17   600 - 1000 DT / Mois                    NaN
# 18        1 - 2 DT / Mois  Locale, International
# 19                    NaN                    NaN

# %%
import pandas as pd

# Load the datasets
df_emploi = pd.read_csv("emploi.csv")
df_keejob = pd.read_csv("keejob.csv")

# Rename columns in df_keejob to match df_emploi
df_keejob.rename(columns={
    "Title": "Job Title",
    "Company": "Company Name",
    "Location": "Region",
    "Job Type": "Contract Type",
    "Publiée le": "Posting Date",
    "Job Link": "Job Link",
    "Étude": "Study Level", 
    "Expérience": "Experience Level"  
}, inplace=True)
print(df_keejob.columns)
# Select and align relevant columns from df_keejob to match df_emploi
df_keejob = df_keejob[["Job Title", "Company Name", "Region", "Contract Type", "Posting Date", "Job Link","Study Level","Experience Level" ]]

# Add missing columns with default values
required_columns = ['Disponibilité', 'Langues', 'Salary', 'Mobility']
for col in required_columns:
    if col not in df_emploi.columns:
        df_emploi[col] = None  # Add column with default value
    if col not in df_keejob.columns:
        df_keejob[col] = None  # Add column with default value

# Ensure the formats of Posting Date are consistent
df_emploi['Posting Date'] = pd.to_datetime(df_emploi['Posting Date'], errors='coerce')
df_keejob['Posting Date'] = pd.to_datetime(df_keejob['Posting Date'], errors='coerce')

# Combine the two datasets
combined_df = pd.concat([df_emploi, df_keejob], ignore_index=True)
combined_df = combined_df.drop(columns=['Job Description'])

# Display the first few rows of the combined DataFrame
combined_df.head()
# Out:
# Index(['Job Title', 'Company Name', 'Region', 'Contract Type', 'Job Link',
#        'Référence', 'Posting Date', 'Type de poste', 'Lieu de travail',
#        'Experience Level', 'Study Level', 'Disponibilité', 'Langues', 'Salary',
#        'Mobility'],
#       dtype='object')
# C:\Users\21692\AppData\Local\Temp\ipykernel_150704\192621615.py:31: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_emploi['Posting Date'] = pd.to_datetime(df_emploi['Posting Date'], errors='coerce')
# C:\Users\21692\AppData\Local\Temp\ipykernel_150704\192621615.py:32: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_keejob['Posting Date'] = pd.to_datetime(df_keejob['Posting Date'], errors='coerce')
#                                            Job Title             Company Name  \
# 0            Business Developer Anglophone​ - Ariana            SMART CONSEIL
# 1                       Community Manager - Monastir           TAHRI COMPAGNE
# 2  Docteur en Data Science ou en Informatique - A...            SMART CONSEIL
# 3           Formation en Data Engineer (F/H) - Paris                KAISCHOOL
# 4  Consultant Fonctionnel Sage XRT ou Sage FRP 10...  DELTASOFT INTERNATIONAL
#
#                                        Study Level  \
# 0  Bac, Bac+1, Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 1                                            Bac+3
# 2                                    Bac+5 et plus
# 3                     Bac+3, Bac+4 & Bac+5 et plus
# 4                                    Bac+5 et plus
#
#                           Experience Level     Contract Type  \
# 0          Etudiant, jeune diplômé et plus  CDI, CDD & Stage
# 1                 Débutant < 2 ans et plus               CDI
# 2  Expérience entre 2 ans et 5 ans et plus         CDI - CDD
# 3          Etudiant, jeune diplômé et plus        Alternance
# 4          Expérience entre 2 ans et 5 ans  CDI - Statutaire
#
#                                               Region  \
# 0                             Ariana & International
# 1                                           Monastir
# 2  Ariana - Béja - Ben Arous - Bizerte - Gabès - ...
# 3                                      International
# 4  Ariana - Béja - Ben Arous - Bizerte - Gabès - ...
#
#                                               Skills Posting Date  \
# 0             Gestion d'Équipe - Prospection - Vente   2024-11-30
# 1  Analyse Marketing - Communication - Communicat...   2024-11-30
# 2                                                NaN   2024-11-30
# 3  APACHE - BIG DATA - Comptabilité - Finance - G...   2024-11-30
# 4  Comptabilité - Finance - Gestion - SAGE - TMS ...   2024-11-30
#
#                                             Job Link Disponibilité Langues  \
# 0  https://www.emploitunisie.com/offre-emploi-tun...          None    None
# 1  https://www.emploitunisie.com/offre-emploi-tun...          None    None
# 2  https://www.emploitunisie.com/offre-emploi-tun...          None    None
# 3  https://www.emploitunisie.com/offre-emploi-tun...          None    None
# 4  https://www.emploitunisie.com/offre-emploi-tun...          None    None
#
#   Salary Mobility
# 0   None     None
# 1   None     None
# 2   None     None
# 3   None     None
# 4   None     None

# %%
print(combined_df.shape)
# Out:
# (1482, 13)

# %%
jobs_with_dash = combined_df[combined_df["Job Title"].str.contains("-", na=False)]

# Display the "Job Title" and "Region" columns of the filtered DataFrame
jobs_with_dash[["Job Title", "Region"]]   #bon lahne meghir manfas5 il region mil title 5ter tw naamlo recherche mouch bil kilma kemla mais plutot containt blabla ...
# Out:
#                                               Job Title  \
# 0               Business Developer Anglophone​ - Ariana
# 1                          Community Manager - Monastir
# 2     Docteur en Data Science ou en Informatique - A...
# 3              Formation en Data Engineer (F/H) - Paris
# 4     Consultant Fonctionnel Sage XRT ou Sage FRP 10...
# ...                                                 ...
# 1373             Stage Pré-Embauche : Community Manager
# 1375              Stage Pré-Embauche : Graphic Designer
# 1390              Stage Pré-Embauche : Vidéaste/Monteur
# 1418                              Import-Export Manager
# 1446                                     aide-comptable
#
#                                                  Region
# 0                                Ariana & International
# 1                                              Monastir
# 2     Ariana - Béja - Ben Arous - Bizerte - Gabès - ...
# 3                                         International
# 4     Ariana - Béja - Ben Arous - Bizerte - Gabès - ...
# ...                                                 ...
# 1373                                              Tunis
# 1375                                              Tunis
# 1390                                              Tunis
# 1418                                              Gabes
# 1446                                          Ben Arous
#
# [262 rows x 2 columns]

# %%
# Clean the contract types by stripping spaces and replacing unwanted characters
combined_df["Contract Type"] = combined_df["Contract Type"].str.strip()  # Remove leading/trailing spaces

# Remove commas, replace them with nothing (i.e., strip commas)
combined_df["Contract Type"] = combined_df["Contract Type"].str.replace(",", "", regex=False)

# Replace '&' and '/' with '-'
combined_df["Contract Type"] = combined_df["Contract Type"].str.replace(" & ", "-", regex=False)  # Replace '&' with '-'
combined_df["Contract Type"] = combined_df["Contract Type"].str.replace(" / ", "-", regex=False)  # Replace ' / ' with '-'
combined_df["Contract Type"] = combined_df["Contract Type"].str.replace("/", "-", regex=False)  # Replace ' / ' with '-'

# Split the "Contract Type" column by '-' and then flatten the values
split_contract_types = combined_df["Contract Type"].str.split("-", expand=True).stack()

# Drop any empty or NaN values and remove extra spaces
split_contract_types = split_contract_types[split_contract_types.str.strip() != '']

# Further split by spaces to make the contract types more logical
split_contract_types = split_contract_types.str.split(" ", expand=True).stack()

# Normalize by stripping any remaining spaces
split_contract_types = split_contract_types.str.strip()

# Get the unique contract types and sort them
unique_contract_types = sorted(split_contract_types.unique())

# Display the unique contract types
print(unique_contract_types)
# Out:
# ['', 'Alternance', 'CDD', 'CDI', 'Fonction', 'Freelance', 'Indépendant', 'Intérim', 'PFE', 'SIVP', 'Saisonnier', 'Stage', 'Statutaire', 'Temps', 'Unspecified', 'partiel', 'publique']

# %%
# Clean the contract types by stripping spaces and replacing unwanted characters
combined_df["Study Level"] = combined_df["Study Level"].str.strip()  # Remove leading/trailing spaces

# Remove commas, replace them with nothing (i.e., strip commas)
combined_df["Study Level"] = combined_df["Study Level"].str.replace(",", "", regex=False)

# Replace '&' and '/' with '-'
combined_df["Study Level"] = combined_df["Study Level"].str.replace(" & ", "-", regex=False)  # Replace '&' with '-'
combined_df["Study Level"] = combined_df["Study Level"].str.replace(" / ", "-", regex=False)  # Replace ' / ' with '-'
combined_df["Study Level"] = combined_df["Study Level"].str.replace("/", "-", regex=False)  # Replace ' / ' with '-'

# Split the "Contract Type" column by '-' and then flatten the values
split_Study_Levels = combined_df["Study Level"].str.split("-", expand=True).stack()

# Drop any empty or NaN values and remove extra spaces
split_Study_Levels = split_Study_Levels[split_Study_Levels.str.strip() != '']

# Further split by spaces to make the contract types more logical
split_Study_Levels = split_Study_Levels.str.split(" ", expand=True).stack()

# Normalize by stripping any remaining spaces
split_Study_Levels = split_Study_Levels.str.strip()

# Get the unique contract types and sort them
unique_Study_Levels = sorted(split_Study_Levels.unique())

# Display the unique contract types
print(unique_Study_Levels)
# Out:
# ['', '+', '1', '2', '3', '4', '5', 'Bac', 'Bac+1', 'Bac+2', 'Bac+3', 'Bac+4', 'Bac+5', 'Doctorat', 'Expert', 'Formations', 'Primaire', 'Qualification', 'Recherche', 'Secondaire', 'avant', 'bac', 'et', 'plus', 'professionnelles']

# %%
offers_with_avant = combined_df[combined_df["Study Level"].str.contains("Doctorat", case=False, na=False)]

# Display the filtered offers
print(offers_with_avant)
# Out:
#                                      Job Title       Company Name Study Level  \
# 560        Un Spécialiste en Pharmacovigilance                NaN    Doctorat
# 764                     Business Développement        PHARMAGHREB    Doctorat
# 799     Délégué médical sur la région du Tunis                NaN    Doctorat
# 1013  Chargé(e) Validation (Assurance Qualité)               CRIT    Doctorat
# 1104                                Enseignant  UNIVERSITE SESAME    Doctorat
#
#       Experience Level                        Contract Type     Region Skills  \
# 560   Entre 1 et 2 ans                             CDI  CDD     Ariana    NaN
# 764   Entre 2 et 5 ans                             CDI  CDD     Ariana    NaN
# 799   Entre 1 et 2 ans                             CDI  CDD      Tunis    NaN
# 1013  Entre 2 et 5 ans  CDD  Indépendant-Freelance  Intérim  Ben Arous    NaN
# 1104  Entre 2 et 5 ans                                  CDI     Ariana    NaN
#
#      Posting Date                                           Job Link  \
# 560           NaT  https://www.keejob.com/offres-emploi/211259/un...
# 764           NaT  https://www.keejob.com/offres-emploi/211002/bu...
# 799           NaT  https://www.keejob.com/offres-emploi/211723/d%...
# 1013          NaT  https://www.keejob.com/offres-emploi/211554/ch...
# 1104          NaT  https://www.keejob.com/offres-emploi/211415/en...
#
#      Disponibilité Langues Salary Mobility
# 560           None    None   None     None
# 764           None    None   None     None
# 799           None    None   None     None
# 1013          None    None   None     None
# 1104          None    None   None     None

# %%
unique_Study_Levels=['Bac', 'Bac+1', 'Bac+2', 'Bac+3', 'Bac+4', 'Bac+5', 'Doctorat', 'Expert Recherche', 'Primaire', 'Secondaire','Qualification avant bac', 'et plus', 'Formations professionnelles']

# %%
study_level_counts = {}

# Loop through each unique study level
for level in unique_Study_Levels:
    # Count the number of occurrences where the "Study Level" column contains the level
    count = combined_df[combined_df["Study Level"].str.contains(level, case=False, na=False)].shape[0]
    study_level_counts[level] = count

# Display the result
for level, count in study_level_counts.items():
    print(f"{level}: {count}")
# Out:
# Bac: 243
# Bac+1: 0
# Bac+2: 0
# Bac+3: 0
# Bac+4: 0
# Bac+5: 0
# Qualification avant bac: 42
# et plus: 156

# %%
# Filter the offers that contain "keejob" in the "Job Link" column
keejob_offers = combined_df[combined_df["Job Link"].str.contains("keejob", case=False, na=False)]

# Display the filtered DataFrame
print(keejob_offers)
# Out:
#                                     Job Title  \
# 243                        Conseillers Client
# 244   Chargé(e) de Service Clientèle - Sousse
# 245                   Développeur Java Medior
# 246                                 Acheteuse
# 247                  Ingénieur Qualité Client
# ...                                       ...
# 1477                    commercial immobilier
# 1478                            Coordinatrice
# 1479                Responsable commercial(e)
# 1480    Vendeur/ Caissier Adidas Tunisia mall
# 1481          Responsable ressources humaines
#
#                              Company Name        Study Level  \
# 243                       TELEPERFORMANCE         Secondaire
# 244                              BANK ABC            Bac + 3
# 245                               BINITNS            Bac + 5
# 246   PLASTIC ELECTROMECHANIC COMPANY PEC            Bac + 3
# 247                           ASTEELFLASH            Bac + 5
# ...                                   ...                ...
# 1477                  EPARGNE IMMOBILIERE  Expert, Recherche
# 1478            TECNOCASA SOUSSE CORNICHE            Bac + 3
# 1479                             WOODTODO            Bac + 3
# 1480                               TUNTEX                Bac
# 1481                      CALE CHAUSSURES            Bac + 3
#
#        Experience Level         Contract Type    Region Skills Posting Date  \
# 243   Aucune expérience                   CDI     Tunis    NaN          NaT
# 244       Moins d'un an           Unspecified     Tunis    NaN          NaT
# 245    Entre 2 et 5 ans                   CDI     Tunis    NaN          NaT
# 246    Entre 2 et 5 ans           CDI, ,, CDD  Zaghouan    NaN          NaT
# 247    Entre 2 et 5 ans           Unspecified    Ariana    NaN          NaT
# ...                 ...                   ...       ...    ...          ...
# 1477   Entre 2 et 5 ans           Unspecified    Ariana    NaN          NaT
# 1478  Aucune expérience                  SIVP    Sousse    NaN          NaT
# 1479   Entre 1 et 2 ans           CDI, ,, CDD    Ariana    NaN          NaT
# 1480  Aucune expérience           Unspecified    Ariana    NaN          NaT
# 1481      Moins d'un an  CDI, ,, CDD, ,, SIVP    Nabeul    NaN          NaT
#
#                                                Job Link Disponibilité Langues  \
# 243   https://www.keejob.com/offres-emploi/211206/co...          None    None
# 244   https://www.keejob.com/offres-emploi/210308/ch...          None    None
# 245   https://www.keejob.com/offres-emploi/211371/d%...          None    None
# 246   https://www.keejob.com/offres-emploi/211433/ac...          None    None
# 247   https://www.keejob.com/offres-emploi/212102/in...          None    None
# ...                                                 ...           ...     ...
# 1477  https://www.keejob.com/offres-emploi/210620/co...          None    None
# 1478  https://www.keejob.com/offres-emploi/210600/co...          None    None
# 1479  https://www.keejob.com/offres-emploi/210592/re...          None    None
# 1480  https://www.keejob.com/offres-emploi/210614/ve...          None    None
# 1481  https://www.keejob.com/offres-emploi/210590/re...          None    None
#
#      Salary Mobility
# 243    None     None
# 244    None     None
# 245    None     None
# 246    None     None
# 247    None     None
# ...     ...      ...
# 1477   None     None
# 1478   None     None
# 1479   None     None
# 1480   None     None
# 1481   None     None
#
# [1239 rows x 13 columns]

# %%
#mizelt 5idma 3al posting date , salary , langues , ..... w lazim nzid nraka7 il defined values mta3 experience w study !
